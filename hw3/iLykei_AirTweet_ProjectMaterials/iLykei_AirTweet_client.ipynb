# %% [markdown]
# # iLykei Lecture Series
# # Text Analytics (MLDS 414)
# # Assignment: Sentiment Analysis with Naive Bayes Bag-of-Words Model
#
# ### Y.Balasanov, M. Tselishchev, &copy; iLykei 2023
#
# ## Preparing the data
#
# Data for this project are in the form of a corpus of documents.
# Each document is a tweet regarding an airline service.
# The goal is to identify (predict) the sentiment of the document: +1 for positive, 0 - for neutral and -1 - for negative.
# The training set contains the sentiment column in which allocation of sentiments was done by humans.
# Vocabulary for this project is created from the table of all words in the corpus of documents.
#
# Install necessary libraries

# %%
#!pip install -q matplotlib numpy pandas scikit-learn nltk

# %% [markdown]
# Install `protobuf` following the instructions [here](https://github.com/protocolbuffers/protobuf/blob/main/src/README.md). Then run the following line, it should not result in any error messages.

# %%
# !protoc --python_out=./ *.proto

# %%
import re
import joblib
from datetime import datetime
import pickle

import numpy as np
import pandas as pd
import nltk
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.metrics import log_loss

# %% [markdown]
# Download NLTK modules with stopwords, punctuation, and wordnet.

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to /home/henry/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/henry/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/henry/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# Add some specific stopwords for this corpus.
# Add lemmatizer based on WordNet.

# %%
aircompanies_accounts = ['VirginAmerica', 'United', 'SouthwestAir', 'JetBlue', 
                         'Delta', 'USAirways', 'AmericanAir']
other_stopwords = ['fly', 'flying', 'flight', 'flights', 'plane']

eng_stopwords = stopwords.words('english')
eng_stopwords.extend([w.lower() for w in aircompanies_accounts])
eng_stopwords.extend(other_stopwords)

lemmatizer = WordNetLemmatizer()

# %% [markdown]
# Create function preparing bag-of-words documents.

# %%
def my_tokenizer(tweet):
    # Remove everything but letters:
    tweet = re.sub("[^a-zA-Z]", " ", tweet)
    # Make lower-case:
    tweet = tweet.lower()
    # Tokenize tweet:
    tokens = nltk.word_tokenize(tweet)
    # Remove stop-words:
    tokens = list(filter(lambda token: token not in eng_stopwords, tokens))
    # Lemmatize all tokens:
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return ' '.join(tokens)

# %% [markdown]
# Load pretrained models.
# Note that this document uses only one model: binary Naive Bayes.
# Train and load multinomial model to improve results.
# Experiment with model ensembling if necessary.

# %%
vectorizer_model = joblib.load('models/vectorizer_bernoulli.joblib')
nb_model = joblib.load('models/nb_bernoulli.joblib')

# %% [markdown]
# ## Prepare the process of responding to the tweets in real time
#
# Define global variables for the process.
# Initialized data frame for received tweets.

# %%
tweet_counter = 0     # tweet event counter
BUF_SIZE = 1000       # no need to change this buffer size

# we create buffers in advance:
tweets_df = pd.DataFrame(index=range(0, BUF_SIZE),
                         columns=['time', 'tweet_id', 'text', 
                                  'prob_neg', 'prob_neutral', 'prob_positive'])
start_time = datetime.now()

# %% [markdown]
# Define the event handler.
# Event hadler is a function that executes the logic of responses to the incoming messages with tweets.
# This function is automatically called every time a new message is received from the server. The function has the following steps:
#
# - Identify time stamp;
# - Update the data frame with received tweets;
# - Tokenize the tweet and make it a bag-of-of words;
# - Predict probabilities of classes. This step uses the pre-fitted model uploaded in the memory. The best model must be selected, or an ensembling logic with several models must be defined here;
# - Update the data frame with the predicted probabilities.

# %%
def tweet_handler(tweet_id, text):
    global tweets_df, tweet_counter
    now = datetime.now()
    # update tweets_df dataframe:
    tweets_df.loc[tweet_counter] = [now, tweet_id, text, np.nan, np.nan, np.nan]
    tweet_counter += 1
    # process new tweet
    print(tweet_id, text)
    tokens =  my_tokenizer(text)
    matrix_model = vectorizer_model.transform([tokens]).toarray()
    model_proba = nb_model.predict_proba(matrix_model)
    probs = list(model_proba[0])
    print(f'{probs=}')
    tweets_df.loc[tweet_counter - 1, ['prob_neg', 'prob_neutral', 'prob_positive']] = probs
    return probs

# %% [markdown]
# ## Run the reali-time process
#
# Connect to the server using your credentials stored in `my_credentials.txt`. The file must contain 2 lines: login name (email address) and the streaming password.
# Connect and see how the handler with your model classifies the documents.
# The score reflecting the accuracy of the classification of the test sample will appear in the log at the end of the session.

# %%
from AirTweet_connection import connect

with open("my_credentials.txt",'r') as f:
    lines = f.readlines()
login, password = map(str.strip, lines)

# server options; do not change
host = 'datastream.ilykei.com'      
port = 30019
stream_name = 'AirTweet'
catch_handler_errors = True  # we recommend using TRUE during the test and FALSE during preparation

# make connection with your personal handlers
result = connect(host, port, login, password, stream_name,
                 tweet_handler, catch_handler_errors)
# Out:
# Connecting to datastream.ilykei.com:30019
# Sending login message
# Logged in successfully as  hanliang2023@u.northwestern.edu
# 0 @AmericanAir can I DM you info?
# probs=[0.5099912369703369, 0.4300703134591872, 0.059938449570476025]
# 1 @united u Cancelled Flighted my flight from IAD to JAX. Was supposed to use plane from BNA but u used that plane for another destination instead. 1/2
# probs=[0.9895418799759755, 0.01045680811442399, 1.3119095947787845e-06]
# 2 @united has once again earned a place as the worst airline in the business
# probs=[0.9980200959801963, 0.0011947236578958534, 0.000785180361907653]
# 3 @jetblue thanks
# probs=[0.3250122233275478, 0.1498233700460955, 0.5251644066263567]
# 4 @SouthwestAir: #VIPLiveintheVieyard - first time we tried to redeem pts for *anything*, it really did not go well. #disappointed
# probs=[0.9983037820056505, 0.0016614237411714755, 3.479425317663111e-05]
# 5 @AmericanAir Thank you for being so responsive on Twitter. Truly impressive.
# probs=[0.0076886869513183055, 0.006033046888312136, 0.9862782661603661]
# 6 @JetBlue thanks!
# probs=[0.3250122233275478, 0.1498233700460955, 0.5251644066263567]
# 7 @united who can tell me where they are?
# probs=[0.7449025791644486, 0.20486371315462873, 0.050233707680922425]
# 8 @VirginAmerica Thanks!
# probs=[0.3250122233275478, 0.1498233700460955, 0.5251644066263567]
# 9 @USAirways - is stranding your customers, not reFlight Booking Problems them, and then not answering the phone the way you treat Platinum members?
# probs=[0.9999346138408932, 1.3618755306188335e-05, 5.176740379596182e-05]
# 10 @united this is not true. Gate agents 100% caused this. And we're not helpful. Thanks for making me miss connection!! http://t.co/xAIzW2isml
# probs=[0.938365309136091, 9.480525403693069e-05, 0.06153988560987588]
# 11 @AmericanAir you Cancelled Flight both flights yesterday and rebook me in middle seat. Not acceptable. Upgrade to emergency row would help. #nothappy
# probs=[0.999648813723371, 0.00035096111890540094, 2.2515771938555478e-07]
# 12 @SouthwestAir my first flight ever and flight #4251 is already having technical issues. Faaaannntastic.😭
# probs=[0.9844331682699764, 0.0024968457491393345, 0.013069985980886472]
# 13 @united 8 hours Late Flightr and I'm siting on another plane waiting to leave. I think a credit is in order for this terrible service!
# probs=[0.999998366547926, 1.6293623330189374e-06, 4.089737240077627e-09]
# 14 @SouthwestAir You need to be more accommodating to your loyal customers. Not happy now!
# probs=[0.8899608190997527, 0.004992366141707989, 0.10504681475854208]
# 15 @united Can you explain how it rewards us elite Premiere 1K members?
# probs=[0.6585297652971432, 0.3340632465171911, 0.007406988185665813]
# 16 @AmericanAir needs an entire customer service overhaul @Delta would never treat its customers with anything less that A1 service
# probs=[0.9998918143070151, 4.8027379558732385e-05, 6.015831343083007e-05]
# 17 @SouthwestAir understand weather is an issue but on time Cancelled Flighted reinstated Cancelled Flighted with hardly any updates and doing nothing for me= :(
# probs=[0.999852060413991, 0.0001082371920872595, 3.9702393918677524e-05]
# 18 @JetBlue What's up with lack coffee on 7:30AM flight. Was told someone forgot to load coffee onto the plane. What????? #INeedCoffee
# probs=[0.9998115474305443, 0.00014871747011708592, 3.973509934001277e-05]
# 19 @USAirways so you don't have a pilot now for #clt ✈ #ord for at least another hour. Why on earth would you board the plane? Makes no sense!
# probs=[0.9998843468218355, 7.513464087804339e-05, 4.051853728605044e-05]
# 20 @SouthwestAir I can. Doesn't it seem fair that if our bags need to fit under our seats, we should need to fit in them?
# probs=[0.9761619263849217, 0.023538396779739623, 0.00029967683534163345]
# 21 @SouthwestAir understand you can only do so much but often it seems like a quick request to the desk is all it takes no questions asked.
# probs=[0.9775507684012783, 0.010945787082610814, 0.011503444516110482]
# 22 @united What is the point of a UPC code on checked baggage if you can't tell me where my luggage is? Vacation- day 3: trying on swimsuits...
# probs=[0.9991880927184422, 0.0008029491117290125, 8.958169829099617e-06]
# 23 @JetBlue Why close prechk at 8PM on a Sunday at JFK?  #annoying
# probs=[0.9821506209613634, 0.014568180913455173, 0.0032811981251789214]
# 24 @AmericanAir @USAirways - I'm pregnant with twins and you're going to abandon me overnight in an airport? No hotel? When it's your fault?
# probs=[0.9750878293213229, 0.020858648335970675, 0.004053522342707805]
# 25 .@JetBlue 4 min response time. I'm impressed! I'm in. It's official.  :-) #trueblue  JetBlue gets social.
# probs=[0.8109266527880572, 0.02768723915119136, 0.1613861080607512]
# 26 “@united: @BattierCCIpuppy Your puppy is so cute. We look forward to having both of you on board. Thanks for the high five. ^EY” 👏👏
# probs=[0.000795740961618749, 0.010376564083962328, 0.9888276949544255]
# 27 .@AmericanAir cover a rental car or refund our ticket? - I'll gladly drive 10 hrs home than be stuck here till Tues!
# probs=[0.9987531090445372, 0.0012468120176179018, 7.893784847612187e-08]
# 28 @AmericanAir flt 703, sorry scheduled at 545, phl-mia, a totally chaotic, poorly addressed event.  Sent to three gates in the night
# probs=[0.9998195356749368, 0.00015390051581488562, 2.6563809247855714e-05]
# 29 @AmericanAir Cancelled Flight my flight saying it is cause of weather condition when it was the only flight that was Cancelled Flight
# probs=[0.8976041753922467, 0.10183892005294526, 0.0005569045548097631]
# 30 @JetBlue My Flight 1318 is delayed and I am connecting from Boston. Is it possible to switch me to Flight 118 so I can make my connection?
# probs=[0.98686888324189, 0.012896659683399984, 0.00023445707471077292]
# 31 @united 2nd Late Flight flight today
# probs=[0.9537323600258341, 0.039669102634463625, 0.006598537339700801]
# 32 @AmericanAir Great - thank you.
# probs=[0.024293408971352466, 0.012132222533024874, 0.963574368495622]
# 33 @USAirways sure, just DM'ed you.
# probs=[0.1697403128131895, 0.7898808048441901, 0.040378882342620354]
# 34 @SouthwestAir app error - says click here, can't click not hyperlinked http://t.co/IH5w9nfKz2
# probs=[0.6111325275999122, 0.38502263298173883, 0.003844839418346945]
# 35 @united Follow me back, please, and I'll happily DM you the link because I'd rather not share my travel plans publicly.
# probs=[0.06289726799824683, 0.9339485314847222, 0.0031542005170303567]
# 36 @JetBlue yes. They are working on it. Hoping bag is on the next flight and will deliver home...
# probs=[0.968349956845246, 0.01116857774067805, 0.02048146541407751]
# 37 @AmericanAir Don't require us to memorize a five-word phrase and remember it after we hear another six million options
# probs=[0.9766373611943204, 0.0025783416813734165, 0.020784297124303738]
# 38 @SouthwestAir beautiful day in Seattle! http://t.co/iqu0PPVq2S
# probs=[0.048819033242022886, 0.4321876290270256, 0.5189933377309508]
# 39 @USAirways NOT GOOD. been on hold for 1hour (2x/day) since sun. to book 1-way flt dividend miles. agents send me to on hold hell. #furious
# probs=[0.9999866185499013, 1.3241625148892145e-05, 1.3982494381939532e-07]
# 40 @USAirways #428 delayed due to #frozentoilet #medicalissue #mechanicalissue #dispatchissue We've heard it all! #LetsGo
# probs=[0.9499623642572486, 0.04410686003320984, 0.005930775709543086]
# 41 @USAirways this response doesn't correct the fact that your pilot failed to keep passengers updated
# probs=[0.9966765811982016, 0.0023844008599464457, 0.0009390179418496216]
# 42 @AmericanAir ok no worries. Thanks for the straight story. It's appreciated.
# probs=[0.025586119039517498, 0.009650299868395737, 0.9647635810920837]
# 43 @SouthwestAir bad weather and multiple Cancelled Flighted flights has us all scared!  Noted for next time.
# probs=[0.9988512254371053, 0.0010221897711274086, 0.00012658479176440524]
# 44 @united on a good note, the 2 employees I encountered @ Newark were fabulous. I was very Late Flight for my connecting flight and they got me on!!!
# probs=[0.7858956587359526, 0.006352877597395608, 0.20775146366664593]
# 45 @USAirways Yes, ground crew finally showed up so plane could depart very Late Flight.
# probs=[0.9821550373201791, 0.0017060735899456436, 0.016138889089876828]
# 46 @AmericanAir Thanks for the reply, but a functioning plane four hours ago was the only way to do that. The staff was friendly, tho.
# probs=[0.9656060387699786, 2.2400436012112014e-05, 0.034371560794008674]
# 47 @SouthwestAir It seems odd to be sitting on a plane that gets further delayed and you find out by txt, not the 6 emp working on the aircraft
# probs=[0.9997775261234474, 4.529457971431985e-05, 0.00017717929683841983]
# 48 @SouthwestAir I need to reschedule a flight and I've been on hold for almost an hour. This is ridiculous. Is there a best number to call?
# probs=[0.999997923532493, 2.019022208933464e-06, 5.744530153467552e-08]
# 49 @AmericanAir no space in my seat but thanks to your pilots I'm back 25mn early to Ohare!! Didn't think that was possible!! #sna2ord #1644
# probs=[0.6603108095247545, 0.3110196603366775, 0.028669530138574737]
# 50 @AmericanAir tisk tisk. Rude flight attendants yet again. I can't hang my suit up because I didn't buy first class? @Delta when will I learn
# probs=[0.9993734120351349, 0.0006119809629673016, 1.4607001900452032e-05]
# 51 @SouthwestAir FJBFSC  all I need is receipt showing the 776.20 charge I have on my Amex not the 656.xx that I keep getting sent
# probs=[0.25232566021631203, 0.7422344780087679, 0.005439861774923814]
# 52 @JetBlue they booked me for tomorrow. It's $250 higher. My 1st reservation is PGFRYZ. Get me on standby list 4 tonight would help.
# probs=[0.6914583204652425, 0.3085249414165124, 1.6738118249715898e-05]
# 53 @AmericanAir Is large Wichita Falls Airport not receiving any arrivals? I have called and no one answers. I been waiting for 1 day
# probs=[0.9999586669146435, 1.4897896281241882e-05, 2.643518907565495e-05]
# 54 @AmericanAir thanks for the DM rescheduling. Unfortunately your operations process at LAX is chaos & the reps refused to print the ticket
# probs=[0.9857920225531686, 0.007285208992970969, 0.006922768453867512]
# 55 @united beginning of Feb I called United they said they would send another voucher by mail. Never got anything. #tiredofwaiting
# probs=[0.9976348858775548, 0.0023400601598450124, 2.5053962606096615e-05]
# 56 @JetBlue @ZKatcher @bretharold does it look like to we talked to customer service? http://t.co/vYUAnh4Iqr
# probs=[0.6786596696355178, 0.008817939238332987, 0.3125223911261507]
# 57 @USAirways No one answers your reservation phone line. I need to book travel with a  companion certificate. How do I get through?!!!
# probs=[0.9923444827957499, 0.007651551003831782, 3.9662004134843105e-06]
# 58 @SouthwestAir i hope i can be apart of the team with this job opening!
# probs=[0.2820748826571112, 0.027054369239628343, 0.6908707481032622]
# 59 @USAirways there has been NO one at the Yuma ticket counter for 30 minutes and there are about 30 people in line. Terrible service!!!
# probs=[0.9999887357685016, 5.385419043655436e-06, 5.878812453157127e-06]
# 60 @AmericanAir do you still use DC9's?
# probs=[0.837414716176404, 0.13695928459173037, 0.025625999231865662]
# 61 @JetBlue is gettin fancy! #Mint #LieFlat Nice work on the menu @Saxonandparole #LobsterMac #BloodyMary #JetSetter http://t.co/zf5wjgtXzT
# probs=[0.00684975360263997, 0.4109769509054223, 0.5821732954919396]
# 62 @SouthwestAir where is mines?
# probs=[0.5959442820656962, 0.18376339400325267, 0.2202923239310512]
# 63 @USAirways what happens to frequent flyer miles earned once merger is complete with AA?
# probs=[0.915609511570104, 0.08418215706621103, 0.0002083313636843381]
# 64 @SouthwestAir Beautiful, thanks a ton!
# probs=[0.02298478617073927, 0.038428865240663114, 0.938586348588597]
# 65 @united DM sent.  Thanks.
# probs=[0.19698543694150994, 0.4480885779823123, 0.3549259850761792]
# 66 @united Thanks. Got it straightend out last night.
# probs=[0.666806690805929, 0.04658078519432661, 0.2866125239997461]
# 67 @JetBlue thanks. Home to MSY. TSA precheck agents directing people after photo until scan beyond rude. One grabbed and pushed children.
# probs=[0.9628251979339738, 0.023167770657299774, 0.01400703140872652]
# 68 @USAirways you gladly take the loyal customer's money but when you cause an inconvenience you do nothing to help fix the problem you caused.
# probs=[0.9999990641997671, 8.298644671142824e-07, 1.0593577243065201e-07]
# 69 @JetBlue thanks to O StBernard for taking time to read through page to find info as supervisor felt to insist tho I showed previous comm
# probs=[0.9983057944622491, 0.0007154649302568667, 0.0009787406074909996]
# 70 @AmericanAir Thank you for the response. Much appreciated!
# probs=[0.010078756116645503, 0.0029199736130705624, 0.9870012702702843]
# 71 @USAirways I'm supposed to fly through Dallas. Can you help me get a new itinerary?
# probs=[0.8870498247800424, 0.11111182765215796, 0.001838347567798694]
# 72 @JetBlue Why not deal with that while the plane's on the ground instead of diverting the plane & adding 2 hrs to the flight?
# probs=[0.9244711767335981, 0.06298891695714157, 0.012539906309256908]
# 73 @JetBlue apparently the plane was delayed coming up from San Juan. Monsoon there today?
# probs=[0.9306556556781306, 0.05795707978353433, 0.011387264538332864]
# 74 @AmericanAir forgot to select my ksml on my flight to LA and it's a few minutes under the 24 hour mark. Is there any way to change it?
# probs=[0.992250195887108, 0.007358210681147585, 0.0003915934317418646]
# 75 @USAirways @GregWallace66 Yea, they will give you 5 cents on the dollar!
# probs=[0.8148284169802322, 0.12409059140996853, 0.06108099160979919]
# 76 @united can you get a gate for UA4727?  Turrible.
# probs=[0.9452953956198081, 0.038830170628230465, 0.0158744337519628]
# 77 @AmericanAir why can't @dfwairport have the capability to spread salt on a runway?!
# probs=[0.508137789923139, 0.1927307728844421, 0.2991314371924165]
# 78 @united note: they are traveling w 2yr old. Unreal
# probs=[0.8619318945321256, 0.11926352180156802, 0.01880458366630548]
# 79 @SouthwestAir bag in possession but no clothes in bag??
# probs=[0.9394353972173834, 0.05053028723437629, 0.010034315548239522]
# 80 @AmericanAir I thought all those planes were retired? #MD80
# probs=[0.216447314051348, 0.6376004575580754, 0.14595222839057836]
# 81 @VirginAmerica Is it normal to receive no reply from Central Baggage #baggageissues #smh
# probs=[0.9387361814167191, 0.05990488438192691, 0.0013589342013544026]
# 82 Lol great answer.. “@AmericanAir: @JayFranceschi Our agents are checking in passengers as quickly as possible. We appreciate your patience.”
# probs=[0.7643060842431436, 0.005937427504757521, 0.2297564882521043]
# 83 @VirginAmerica Never had a bad experience before, but this one took the cake. Now extortion for carry on items as well?
# probs=[0.9950016609367898, 0.0004969409649185426, 0.00450139809828709]
# 84 @AmericanAir @Delta @JetBlue can you help? @SpiritAirlines is in the wrong, stuck in Florida 3days. They need to learn from real airlines.
# probs=[0.9995964778194983, 0.0003931974368935453, 1.0324743606428572e-05]
# 85 @AmericanAir would have been had I seen this before 1130pm EST, when I was sound asleep.
# probs=[0.8691164818965871, 0.1002114804318829, 0.03067203767153106]
# 86 @AmericanAir hi my flight to DFW 2463 was Cancelled Flightled tonight. Called in and left my number for call back it's been 3hrs please help.
# probs=[0.9982063786453788, 0.0017933923664811106, 2.2898813850617486e-07]
# 87 @VirginAmerica when can I book my flight to Hawaii??
# probs=[0.28332272667678027, 0.6563066072749602, 0.060370666048260135]
# 88 @united the os isn't controlled by me but rather @VerizonWireless .  App is new.
# probs=[0.7963850455545025, 0.11928529378065318, 0.08432966066484365]
# 89 @USAirways any word on flight 1748 getting out of DFW in the near future? Stuck on plane at gate for over an hour
# probs=[0.9983537140231933, 0.0014547163386972744, 0.0001915696381089563]
# 90 @VirginAmerica hold times at call center are a bit much
# probs=[0.9975375412802884, 0.0005550556043041128, 0.0019074031154103928]
# 91 @SouthwestAir Hi! Just wanted to see if you have any new routes planned this year for Newark. Love flying you guys and hope to do so more!
# probs=[0.020341764217588796, 0.25124346761941013, 0.7284147681629961]
# 92 @united error message said couldn't process request at the last step after seat selection on each leg. Agent was unaware of an (1 of 2)
# probs=[0.9998865201572354, 0.00011318528482263964, 2.9455794273804496e-07]
# 93 @JetBlue shout out to the crew on flight 89 headed back to the big apple, they kept my glass half full the whole flight! #jetbluejfk
# probs=[0.4825442198849756, 0.0019713200248103312, 0.5154844600902087]
# 94 @usairways when trying to check-in online, it says to call...now I've been on hold for 2 hours...what to do?
# probs=[0.9998829936165522, 0.00011693559806742682, 7.078538234068862e-08]
# 95 @SouthwestAir much respect!
# probs=[0.6196828620855441, 0.04080154132248897, 0.33951559659196673]
# 96 @united  bags left behind because plane overweight, be great if knew as soon as we landed, instead letting us wait 45 minutes with no info.
# probs=[0.999729021491468, 0.00020717691201326894, 6.380159651847328e-05]
# 97 @USAirways FINALLY leaving 4 home from NC. Will lodge respectful complaints!! Mechanical issue after cleared for runway? #5hourwait #nocrew
# probs=[0.9710755077821007, 0.006015856015747377, 0.022908636202153474]
# 98 @united as for volunteers to give up seats, people did! Now we sit for 25 minutes on plane waiting 4 them to add more people!  #letsgo
# probs=[0.9763178312172192, 0.0235139723086378, 0.0001681964741391247]
# 99 @United never heard of this? http://t.co/QDebyaHqfM
# probs=[0.6957240229451868, 0.25198324613581596, 0.05229273091899613]
# 100 @united yall should probably work on that.
# probs=[0.6584169718553962, 0.20373662506383153, 0.1378464030807711]
# 101 @SouthwestAir http://t.co/tTXRSyNLxr doesn't work on my flight. Just fyi.
# probs=[0.24009295713873843, 0.5646527553373248, 0.19525428752393809]
# 102 @USAirways stuck at the gate in Charlotte, NC waiting for "release papers" and a fix for a broken computer system.
# probs=[0.9999955867501069, 2.316352287077894e-06, 2.09689760006235e-06]
# 103 @SouthwestAir Redeem-points packages magically gone by time we finally got through @ 10:01, felt like #baitandswitch
# probs=[0.97370746542163, 0.003948534250934988, 0.022344000327437098]
# 104 @USAirways right, can you use a shuttle ticket from LGA to BOS for any shuttle flight? Probably gonna miss the 4pm.
# probs=[0.9312222286794614, 0.06870180255010917, 7.596877043597056e-05]
# 105 @united Currently on standby to Lax then it is a 2 hour ride to Palm Springs. Long day starting at a snowy 3:30 am in philly.
# probs=[0.9764075611221265, 0.02323274096162718, 0.0003596979162402013]
# 106 @AmericanAir thanks for following up. I think it's fair to refund the ticket price and the two one way rental cars I had to buy.
# probs=[0.7532606212684987, 0.24673708924085258, 2.289490655724473e-06]
# 107 @JetBlue's flight Flight Booking Problems experience is pretty great!
# probs=[0.753916263998224, 0.003383557607050654, 0.24270017839472244]
# 108 @united I lost my sunglasses on the flight from OKC to IAH this morning (8am takeoff) .. is there any way to retrieve them?
# probs=[0.6951634134253006, 0.26759812367679126, 0.037238462897913924]
# 109 Includes @KCIAirport “@SouthwestAir: Inclement weather may impact scheduled service in. ReFlight Booking Problems options available: http://t.co/KeyrpFlHil”
# probs=[0.12027181707647092, 0.878676595051868, 0.0010515878716620944]
# 110 @united you'll be hearing from me for sure.
# probs=[0.6830378214574413, 0.2643538999416687, 0.05260827860088968]
# 111 @SouthwestAir I have used you guys for most my travels, but this last experience I will never use southwest again! #worstcustomerservice
# probs=[0.9888737957968468, 0.0025916602402665237, 0.008534543962884672]
# 112 @united @NY_NJairports Only at Newark can you land 15 minutes early but lose all that time waiting on tarmac for a gate.
# probs=[0.9999959363339033, 2.5580845588484083e-06, 1.505581537985666e-06]
# 113 @AmericanAir flight 3056 still sitting at DFW waiting for baggage to be loaded
# probs=[0.9997733148250895, 0.00016797529684075546, 5.870987806712296e-05]
# 114 @USAirways @AmericanAir won't even refund for a flight they Cancelled Flightled #horriblecustomerservice
# probs=[0.9964722947358955, 0.0032842772354775957, 0.0002434280286250005]
# 115 @united feeling poor on the church-mouse level here, 180 dollars is enough to make a grown man cry. I'm not a grown man but tears happened
# probs=[0.9975207214275583, 0.00204610472529681, 0.0004331738471516632]
# 116 @VirginAmerica is helping me step up my @Tinder game! #TinderTips #tinderchamp http://t.co/jBmVVha63A
# probs=[0.41349422918653317, 0.1271042644219265, 0.45940150639153704]
# 117 @AmericanAir the folks at the Executive Platinum desk are great pros.  They understand my displeasure with change fees and switch to SW.
# probs=[0.9633331803255725, 0.0037568382211916737, 0.03290998145324207]
# 118 @AmericanAir @maryella_green despite the inconvenience, the situation was handled quickly and we appreciate it very much!
# probs=[0.00870678878402624, 1.0227916248288247e-05, 0.9912829832997289]
# 119 @united where is my flight voucher?
# probs=[0.7811030620944496, 0.1327178601191411, 0.0861790777864095]
# 120 @AmericanAir now we are waiting on nitrogen for the struts and the airport nozzle is not calibrated so they are trying to find another???
# probs=[0.9947054118145494, 0.004652857850904854, 0.0006417303345428179]
# 121 @united you better hold my flight to Tucson #5237, just landed in Houston after an hour delay for some minor computer problem
# probs=[0.9999856868731617, 4.639535395655168e-06, 9.673591438561336e-06]
# 122 @AmericanAir 8:30 departure?  Sure. Is there a catering strike at JFK?  @FoxNews @CNBC @BloombergRadio http://t.co/HPgXYZRW8o
# probs=[0.7536053063665102, 0.2262479132597554, 0.02014678037373536]
# 123 @USAirways link didn't work via Mobil.
# probs=[0.6492737023633427, 0.308735042745306, 0.041991254891353025]
# 124 @JetBlue   Phone agents can't see same flights I see online???  Can't change tickets even when I am paying. Very frustrating #jetblue
# probs=[0.9998619994466112, 0.00013041914483771905, 7.581408549335767e-06]
# 125 @united Making sure your flights aren't delayed due to poor maintenance would be a start.
# probs=[0.9997912915009863, 0.00017140924746412398, 3.729925155299875e-05]
# 126 @USAirways
# This is how vacations get Cancelled Flightled been on hold ⤵for 40+ minutes still havent talked to anyone. #failure http://t.co/ef4P0HISHb
# probs=[0.9999966519894683, 2.9539807169696697e-06, 3.9402982091781443e-07]
# 127 @SouthwestAir Katie, Gate C47, Denver International, fantastic customer service helping me and 2 new flyers; thx for amazing staff!
# probs=[0.04052559688851764, 6.509532285844805e-06, 0.9594678935791976]
# 128 @USAirways only happened because u couldn't get us home the next day. #flydelta #flysouthwest #flyjetblue #theyareallbetter #stillnobags
# probs=[0.96975388551723, 0.020930907447598696, 0.009315207035173734]
# 129 @SouthwestAir yea but I was hoping to avoid the ticket difference amount as a birthday courtesy? #flysouthwest #lovesouthwest #mybday
# probs=[0.6292231822396864, 0.35493967553236194, 0.015837142227956742]
# 130 @united 4 people MCI to DEL. Preferably with Jet Airways EWR-BRU-DEL segment. Anytime in December
# probs=[0.09305530355640473, 0.8696884683776083, 0.037256228065992984]
# 131 @JetBlue knew that ... has to be done at the Gate correct? If so what time does gate open
# probs=[0.9699569900533247, 0.026441192782513927, 0.0036018171641614663]
# 132 @AmericanAir TSA said there is nothing they could do. But the question is why are your employee's swapping your customers belongings?
# probs=[0.998631865768397, 0.001202726824861542, 0.00016540740674057583]
# 133 @USAirways How soon is possible? I boarded the plane the 1st time at 6:30 am and it is now after 11:30 am and I'm still where I started.
# probs=[0.9572358775263992, 0.04089117701032388, 0.0018729454632784468]
# 134 @united seriously what's with the slow #wifi on this flight! If the speed was going to change for the worse then the price shouldn't go up!
# probs=[0.9998989000307414, 9.008698940649535e-05, 1.101297985721033e-05]
# 135 @united can I access Frankfurt arrival lounge when I'm flying global first class?
# probs=[0.36600145963427627, 0.4204441861626927, 0.2135543542030301]
# 136 @united We were supposed to board at 605. They just brought the plane from the hanger! WTF did they not know there was a flight?1153 Lax-EWR
# probs=[0.9893049777033368, 0.008607863988301278, 0.0020871583083637317]
# 137 @USAirways @AmericanAir no, don't leave me!!!
# probs=[0.8068874714876687, 0.1679461650040271, 0.025166363508304302]
# 138 @USAirways  my flight was #3729...but I left my phone on the plane or the shuttle :(
# probs=[0.8371647750773564, 0.15390754269040016, 0.008927682232244915]
# 139 @united exactly
# probs=[0.5628881284813576, 0.15621327772085816, 0.2808985937977834]
# 140 Reply to @united - Doesn't do any good to check outlets preflight when moved to different equipment after boarding due to malfunction.
# probs=[0.9922862775748839, 0.007257930989498885, 0.00045579143561393076]
# 141 @united this happens all the time.  United pilots are always in the exit row.  America treats there customers better than their employees.
# probs=[0.9873902658387761, 9.935899440177096e-05, 0.012510375166820858]
# 142 @JetBlue PDX to JFK was suuuuper HOT.
# probs=[0.2962266614853019, 0.15961545735410618, 0.5441578811605913]
# 143 @united fyi the site/app still shows plenty of the unavailable flights I had errors with. Almost 24 hrs after sellout. Flying @AmericanAir
# probs=[0.9998594528042748, 0.00013996402553812857, 5.831701924176111e-07]
# 144 @JetBlue when are you going to get wifi on your planes?
# probs=[0.9643068118132689, 0.027118888994668255, 0.008574299192064306]
# 145 @AmericanAir @tennetexan Too bad there's only, like, 3 people on that team, then. Because this is next level unreal.
# probs=[0.9789193696431185, 0.0022134564864215805, 0.01886717387045674]
# 146 @SouthwestAir big thanks to your team. family emerg, same day ticket, experience was excellent. 1st time flying with yall, not my last!
# probs=[0.2771274945500593, 0.00013923466505640078, 0.7227332707848804]
# 147 @united I was protected on that flight by gate agent Kerry at LAS. She also did an excellent job getting me to my destination today. Thanks!
# probs=[0.13978033524999078, 0.00031078104481918086, 0.8599088837051844]
# 148 @AmericanAir need2know if Ill be able to reach IND today.Rather stay in MAF that fly to DFW & find out I can't travel http://t.co/gVgKHbx1RB
# probs=[0.9805150227451175, 0.013692062162157044, 0.00579291509273208]
# 149 @SouthwestAir Southwest is scheduled to fly to Costa Rica on March 7 but I can't book it online. When will this be available?
# probs=[0.2946941728716632, 0.7052242749439976, 8.1552184344617e-05]
# 150 @AmericanAir you need to have a look at your handling of flight 106 and 104. Company of yours size should have protocols in place to help
# probs=[0.9931678182694621, 0.0029852907003040446, 0.003846891030233263]
# 151 @SouthwestAir been on hold so long to rebook my Cancelled Flightled flight I had enough time to rebook with @USAirways instead! Lots of room there!
# probs=[0.9999762067114576, 2.3723227206554623e-05, 7.006133931432642e-08]
# 152 @SouthwestAir looks like Bellagio to me! Good luck people! See you at the show at Vinyl
# probs=[0.30671248151056957, 0.2590694826002837, 0.43421803588915003]
# 153 @united sorry for the delayed response. It was UA #381 Chicago to San Fran. Held up for almost an hour on the Tarmac. Also, lost my bags
# probs=[0.999999214507095, 3.878582431407275e-07, 3.976346675227369e-07]
# 154 @SouthwestAir @geekstiel Do you know when the last chance is?
# probs=[0.6058015109006619, 0.36668891842776463, 0.027509570671574]
# 155 @united but the gate agent and club staff got me priority standby for next so might only be minor disaster...#travelingwithsmallkids
# probs=[0.9964120311968326, 0.00018157792073799186, 0.003406390882434468]
# 156 @JetBlue imma need the hook up tho
# probs=[0.45558653225845597, 0.4792704393813451, 0.06514302836019703]
# 157 @VirginAmerica @JezzieGoldz would have been a rough trip but LUCKILY we were on a #virginamerica flight. #weather
# probs=[0.4635152478090123, 0.43448083005706634, 0.10200392213392448]
# 158 @united my last call your customer service agent called me back... As he was stuck on hold to air Canada.. Just hope he's booked me a flight
# probs=[0.9999969934025054, 1.806258859120674e-06, 1.2003386376016516e-06]
# 159 @USAirways what's up with flight 5545 no gate agent or plane at PHX B18?  Nice customer service.
# probs=[0.9548322762549987, 0.0001599924234413451, 0.04500773132155801]
# 160 @united no I don't. Spoke with baggage contact at 1-800 number. Said they will try to get bags to stay at IAD for pick up tmrw
# probs=[0.9992419476330167, 0.0007558122948564516, 2.2400721252574603e-06]
# 161 @united this is very disappointing. This is about customer service.
# probs=[0.981207931091799, 0.0015300565986100152, 0.017262012309590666]
# 162 @SouthwestAir I hope this isn't a real life scene out of the movie 'Flight' .....
# probs=[0.8370326074306269, 0.01810174533247214, 0.14486564723690054]
# 163 @JetBlue why haven't you allowed for flight changes into the NY area airports tonight?  Everyone is saying travel is treacherous.
# probs=[0.9840668230777547, 0.015006266816458651, 0.0009269101057808489]
# 164 @AmericanAir how do you refuse a customer who is willing to pay to upgrade when half of your first class is empty
# probs=[0.9996231911068537, 0.0003640596745090842, 1.2749218642766455e-05]
# 165 @usairways @BarclaycardUS 1 hr wait so far for customer service. yes bad weather but do air traffic controllers answer your phones?!??
# probs=[0.9999913985414414, 2.525060725828587e-07, 8.348952483738396e-06]
# 166 @AmericanAir we are waiting flight 919 !
# We are at JFK for about 24h !! #NewYork #919 #viracopos #AmericanAirlines http://t.co/3FheS0lPMU
# probs=[0.7461027467422598, 0.16023280924426309, 0.09366444401347923]
# 167 @AmericanAir you flew me into Chi instead and I got a ride to MKE. U said my bags would go to MKE today. Is it on the Cancelled Flightled flight tho?
# probs=[0.9997732039785256, 5.9641569249340543e-05, 0.00016715445222644879]
# 168 @JetBlue should i continue?
# probs=[0.6431965048944136, 0.16227321713953863, 0.1945302779660472]
# 169 @AmericanAir Oh, and losing my luggage #ridiculous # angrybird # where'smybag
# probs=[0.9991833176258559, 0.000525645754088027, 0.00029103662005727755]
# 170 @SouthwestAir last 5 flights have all consistently ran behind schedule what's up with that ??
# probs=[0.9220748306552325, 0.057809348481480206, 0.020115820863290598]
# 171 @USAirways what is going on with the computers? Why is my flight grounded? Why does your airline suck so much? #UnansweredQuestions
# probs=[0.9950959955831217, 0.0006252319330058399, 0.00427877248387179]
# 172 @JetBlue I had a SJC to JFK departing 10:55pm tonight. I have to now change my whole schedule. Can we get a sort of refund for this?
# probs=[0.8360552879205919, 0.16385478992394464, 8.992215546641193e-05]
# 173 @SouthwestAir is the contest over for Destination Dragons? I want to try to do everything I can to go.
# probs=[0.051582197960606306, 0.8982747956107415, 0.05014300642865245]
# 174 @USAirways YOU ARE THE BEST!!! FOLLOW ME PLEASE;)🙏🙏🙏✌️✌️✌️🙏🙏🙏
# probs=[0.13927999404306554, 0.43111541167745654, 0.42960459427947906]
# 175 @SouthwestAir How do I retroactively add previous flights/miles/points to current rapid rewards balance?
# probs=[0.027610908084551748, 0.9723223857597086, 6.670615574501779e-05]
# 176 @united I travel a lot and I get it. You're still my fave but EWR to Cleveland w/40 min layover to connect to DC = our best option? Come on.
# probs=[0.98491625944462, 0.01474675236128899, 0.0003369881940897284]
# 177 @united I am a frequent user. Congrats u only lost my bags once in 20 years. Problem, it was today and your staff were rude!😢 still no bag!
# probs=[0.9993694365660059, 7.947451729200574e-05, 0.0005510889167069434]
# 178 @united an update on flight 5979 would be great!
# probs=[0.5843884373327404, 0.07020253824951891, 0.3454090244177392]
# 179 @AmericanAir @dogbuckeye No, I was on hold for 4 1/2 hours.  3 diff agents each w/ different information, frustrating, kept getting txfd...
# probs=[0.999996398584576, 1.526197288271138e-06, 2.07521813821218e-06]
# 180 Alright... Someone has to stop this! RT @JetBlue: Our fleet's on fleek. http://t.co/lchVJoliDg
# probs=[0.00029238060761172495, 0.9992065456715378, 0.0005010737208474165]
# 181 @VirginAmerica when are you flying to hawaii
# probs=[0.2540351127678999, 0.5875006597481137, 0.15846422748398678]
# 182 @JetBlue where exactly can I leave a note
# probs=[0.8715807415114795, 0.07895565054230239, 0.04946360794621913]
# 183 @USAirways I appreciate the hard work. Still, I gave up after >hour. @dsearls
# probs=[0.9831896304751965, 0.00025700120656759487, 0.01655336831823379]
# 184 @AmericanAir I'm flying into DCA my bag is at IAD.  I am already Late Flight for my meetings at work.  I will call the number when I land 😭
# probs=[0.999655322739714, 0.0003407108828763884, 3.966377404447253e-06]
# 185 @SouthwestAir By the way the flight number was 1703, please feel free to fact check my complaints about leave time & baggage time.
# probs=[0.9987802407301353, 0.0012025476903255326, 1.721157954137411e-05]
# 186 @AmericanAir hey ho its not me losing any money (only you) just next make sure you stick to the "flyers right's booklet"
# probs=[0.8854392722342257, 0.11154766321429978, 0.0030130645514758417]
# 187 @USAirways not to mention the fact that my flight was delayed BECAUSE YOUR COMPUTERS WERE DOWN
# probs=[0.9976309396187059, 0.0009428279211300917, 0.0014262324601650481]
# 188 @AmericanAir I had booked online but unable to Cancelled Flight online. But finally got thru.
# probs=[0.9982043073299514, 0.0015338403005379154, 0.00026185236950797817]
# 189 “@united: @ItsAaronChriz Sorry to hear about your flight. Do you need help reFlight Booking Problems?”
#
# 👎
# probs=[0.9508819520559083, 0.04649324160452172, 0.002624806339570526]
# 190 @united what do you think missing meetings is worth?  A flight voucher?  I fly all the time, so what would make it right?
# probs=[0.9979498742316802, 0.0018791682730876847, 0.00017095749523439596]
# 191 @USAirways @DRVRugby  team is back home but luggage all wet and partly damaged - Not happy! #blizzard
# probs=[0.9848787488862767, 0.00035096322233340454, 0.014770287891395973]
# 192 @USAirways 40 minutes to put my TSA number in… 40 mins… and stop holding people hostage with requiring a dividends miles acct. @tsa
# probs=[0.9999611358276567, 3.8791042076903466e-05, 7.313026365151104e-08]
# 193 @united flight attendant regains karma by giving big sweaty dad cold water. Guy was running & carrying his daughter.  Last one onboard.
# probs=[0.8486529784195623, 0.004959998853602376, 0.14638702272683546]
# 194 @united DM sent.  This lack if customer service is getting ridiculous.
# probs=[0.9997564428020486, 9.137790654621017e-05, 0.00015217929140752345]
# 195 @AmericanAir pretty impressed with the in flight entertainment. Full touch, usable, smooth, good selection.
# probs=[0.15143338860272249, 0.012957048754960685, 0.8356095626423155]
# 196 .@SouthwestAir I appreciate that, and not to be rude, but it doesn't solve much. You should AT LEAST cover the cost of stolen goods.
# probs=[0.9980166340653145, 0.00037921356042140757, 0.0016041523742669056]
# 197 @southwestair,  kudos to your rep "Patricia" at gate B11 this Sunday morning at #Chicago #Midway #MDW,… http://t.co/MmCWkqp2gy
# probs=[0.018891588808361625, 0.01982664154773702, 0.9612817696438948]
# 198 @USAirways : You Make the Reservation; We'll Make the Excuses! #usairwaysfail
# probs=[0.983052771183334, 0.01574282023484134, 0.0012044085818258155]
# 199 @southwestair I have a roundtrip ticket now and I need to change one leg of the trip (to a nearby airport) - not possible via website?
# probs=[0.4334303346804343, 0.5665670297497492, 2.6355698191637964e-06]
# 200 @united maybe one day you'll be the one quoted on http://t.co/mJkpgVXmPC
# probs=[0.49531652351715105, 0.4518956275627701, 0.05278784892007953]
# 201 @AmericanAir I have looked and I was told it was in Guatemala last night. No record of anywhere today. I need my clothing for work tomorrow.
# probs=[0.9632485798091394, 0.03655666453374277, 0.0001947556571241144]
# 202 @united web app won't let me upgrade seats, call center wait time is 20 minutes plus, just want to get more legroom but it's a pita
# probs=[0.999979793805034, 1.0853132247004737e-05, 9.35306272500166e-06]
# 203 @JetBlue Even though this flight #226 didn't have much needed hot beverages 4 us NY-ers, the landing was super smooth 👍👍 😊 #happytweet
# probs=[0.009093549943693222, 0.0006569784281917525, 0.9902494716281116]
# 204 @SouthwestAir please acknowledge Attendant Jeff Wernicke. Beat in class and service on SW
# probs=[0.313050799927988, 0.05530602967211828, 0.6316431703998912]
# 205 @USAirways What was the point of the merger?  Why not just go out of business if your not turning a profit anymore?
# probs=[0.8131337701073893, 0.18623227314934723, 0.0006339567432603002]
# 206 @JetBlue just lost very loyal customers who use them 4-10 times a year.
# probs=[0.9896570299124283, 0.0011390146026663283, 0.00920395548490505]
# 207 @united Fair enough. I don't usually rant, but it's good to know someone's listening. :)
# probs=[0.9382006796943051, 0.040526603407213695, 0.02127271689847906]
# 208 @SouthwestAir me & @sammi_jon3s are best friends because of @Imaginedragons. Any chance we could get tickets to #DestinationDragons ?
# probs=[1.5075372692363782e-05, 0.9975923444592004, 0.0023925801681025836]
# 209 @united My favorite way to travel! Thank you! http://t.co/vGN2X1ckg0
# probs=[0.004048969186945829, 0.3931749238965489, 0.602776106916507]
# 210 @AmericanAir what's the status of flight 1357 out of sju?
# probs=[0.6985249664591636, 0.1789429208980747, 0.12253211264276048]
# 211 @united Could this email be resent as it doesnt appear to have arrived.
# probs=[0.8153417942042158, 0.17917334864434722, 0.005484857151437392]
# 212 @united what do you have in mind?
# probs=[0.5196516577432521, 0.1201785408469483, 0.36016980140979993]
# 213 @united dmangen@visualclubconcepts.com
# probs=[0.5222756875269683, 0.4294591774594026, 0.04826513501362859]
# 214 @united :take note of this great example of @JetBlue actually making good for an extremely inconvenient situation. http://t.co/t3Gnk2N7LD
# probs=[0.27041452251116554, 0.00017001830094262919, 0.7294154591878965]
# 215 @USAirways flight 2120. Please get us a flight plan already. How is this an issue in 21st century?
# probs=[0.767703387235132, 0.23053554708701698, 0.0017610656778526423]
# 216 @AmericanAir Im trying to call and book a reward ticket on one world partners but your automated system wont let me talk to any1.  Great job
# probs=[0.9999505728308241, 4.898421252351159e-05, 4.429566594353497e-07]
# 217 @USAirways A tweeted apology is not enough for delay fiasco. NONE for insult from gate agent is worse. Except for Mark N., all bad at CLT.
# probs=[0.9999916509929473, 2.861940838520177e-08, 8.320387642279128e-06]
# 218 @USAirways Still waiting for another crew member. #cabinfever
# probs=[0.9962044618095688, 0.0008467923266268729, 0.002948745863803645]
# 219 @JetBlue I know where you guys jet! LOL, but if you love me so much, help a brother out :) Hot weather, great nightlife, 2-3 hour flight
# probs=[0.19253799468473018, 0.0029833185150211746, 0.8044786868002421]
# 220 @united Hopefully They will give me a feedback, bafore my flight...
# probs=[0.7391701598582314, 0.19099236442771528, 0.06983747571405427]
# 221 @SouthwestAir I'm teaching new #travelers how to research, #budget & #save for a trip today! http://t.co/Qll48r57ep
# probs=[0.0011007918467974653, 0.9906721195903929, 0.008227088562812927]
# 222 @AmericanAir you have my money, you change my flight, and don't answer your phones! Any other suggestions so I can make my commitment??
# probs=[0.99706757412265, 0.002841211986377821, 9.121389097558293e-05]
# 223 @USAirways And the lies continue. Just waited another hr to get boarding passes for flight supposedly created today which is now Cancelled Flightled?!
# probs=[0.9999608439623546, 3.858246428072776e-05, 5.735733716593652e-07]
# 224 @SouthwestAir  Just left there  Friday!
# probs=[0.5899762843045568, 0.3215443091485679, 0.08847940654687561]
# 225 @united Do you have any flights with lie flat seating from STL to PDX around the date of March 5?
# probs=[0.007903990635458656, 0.9917390206834574, 0.0003569886810828501]
# 226 @AmericanAir Kudos to the crew of Flt 167 today. Specially to Carlton. Loved your new 767-300. Keep up the good work AA!
# probs=[0.035497448673516, 5.059559946710791e-05, 0.964451955727014]
# 227 @united @RenoAirport hi, when do direct flights from Houston to Reno begin?  Don't see any days in March?
# probs=[0.11273806837797985, 0.8688759839970287, 0.01838594762499415]
# 228 @JetBlue took forever for catering to get to my flight, now are very delayed. So ticked off right now.
# probs=[0.9939467076524703, 0.002814432163720588, 0.0032388601838072317]
# 229 @JetBlue how much longer to JFK open's I am a diabetic and I need sugar plane don't have nothing
# probs=[0.9588525630854554, 0.03916810485780753, 0.0019793320567345705]
# 230 @united look at this beauty 😉 dc 10 united airlines 😉 http://t.co/MvYoizRPdE
# probs=[0.055258326038093546, 0.7268063061868951, 0.21793536777501066]
# 231 @united is the worst. Worst reservation policies. Worst costumer service. Worst worst worst. Congrats, @Delta you're not that bad!
# probs=[0.9998184150055371, 0.00012394562287124626, 5.7639371594957375e-05]
# 232 @AmericanAir the customer service today is unsat, Flight cnx, not notified, called for 6 hours and the phone line does not even let me hold
# probs=[0.9999992861855834, 1.4441999859620784e-07, 5.693944158510466e-07]
# 233 @USAirways We've been sitting on this plane for almost an hour, waiting for it to be fueled. Shouldn't that have been done b4 we got on????
# probs=[0.9996990040246039, 0.00011515977913587522, 0.00018583619625660286]
# 234 @united flew from sdf to ATL to Tampa on Delta. Left early. Arrived early. Crew helpful. Wifi worked!!
# probs=[0.30429156089091924, 4.180432704951052e-05, 0.6956666347820363]
# 235 @united I am trying to book awards for September and need flights on @aegeanairlines but they will not show even w/ many award seats availab
# probs=[0.7306562413604815, 0.26889075425001574, 0.00045300438950195317]
# 236 @united it's a shame the great customer service wasn't continued in SFO. Slightly absurd
# probs=[0.9361293993949824, 0.0004807673597144604, 0.06338983324529977]
# 237 @AmericanAir don't worry. I'll be sending a letter with what I expect from you for compensation. I fly twice a week w/you guys...for now
# probs=[0.9956028191916536, 0.0020561578377483376, 0.002341022970596274]
# 238 @usairways  my flight has been Cancelled Flightled. On hold for 2+ hrs to reschedule. Need help now.  Taking way too long http://t.co/NeHnsDCkTY
# probs=[0.9997032179423592, 0.0002966091790665197, 1.7287857565784167e-07]
# 239 @AmericanAir thank you for the confirmation.
# probs=[0.12867436854064254, 0.25855392336016775, 0.6127717080991892]
# 240 Thanks @united for writing back. To assist you can return the bag you lost & clean up the feces sprinkled in your bathroom. Too much to ask?
# probs=[0.9928356262089343, 0.0022279027549725475, 0.004936471036097349]
# 241 @AmericanAir It's our honeymoon,I paid extra business. I was sitting next to my bride, you bumped me because of status. Disgusted
# probs=[0.9998733337548574, 0.00012045289453344433, 6.213350613359754e-06]
# 242 @JetBlue then this agent demanded I remove my old luggage tag, every other airport the JB agent politely handles it
# probs=[0.9992815321102722, 0.00015155340932296841, 0.00056691448040175]
# 243 @USAirways sure knows how to pamper customers they strand abroad. #badcustomerservice #fend4yourself #youareonyourown http://t.co/Pw1eudlcZg
# probs=[0.39082545477855224, 0.44232820379686233, 0.16684634142458818]
# 244 @USAirways & @AmericanAir what are your weight restrictions for carry on luggage? Can find measurements but not weight restrictions. TIA
# probs=[0.9487976406799431, 0.05048501997613155, 0.0007173393439286715]
# 245 @AmericanAir Here is the photo ;) http://t.co/VMqUURZUpW
# probs=[0.007665164822289602, 0.8923366440470674, 0.099998191130643]
# 246 @united i'm glad u can solve the prob. But my experience remains - will not fly again on #United
# probs=[0.6604202548868898, 0.027569626180169976, 0.31201011893293745]
# 247 @AmericanAir delivered mom's delayed bag to the wrong place. 2 hrs on hold yesterday, >1 hr today. Still no bag. #AA http://t.co/QKkJdFObOS
# probs=[0.9999921367974943, 7.657103831088085e-06, 2.060986792282895e-07]
# 248 @AmericanAir found out my flight tomorrow was Cancelled Flightled & got in the queue for a callback 3.5 hours ago…still nothing. Can I get rebooked??
# probs=[0.9999993384383771, 6.549028115881558e-07, 6.6588125999563986e-09]
# 249 @USAirways There isn't a ticket number...the transaction is still pending.
# probs=[0.9788029615528975, 0.019903563229639112, 0.0012934752174651625]
# 250 @VirginAmerica you know what would be amazingly awesome? BOS-FLL PLEASE!!!!!!! I want to fly with only you.
# probs=[0.28701764039975947, 0.36884071837095, 0.3441416412292918]
# 251 @SouthwestAir  I can go.  I want to badly!!!!   I don't know how to DM.  Can I e-mail you?   Help!!!  wmn4life@hotmail.com
# probs=[0.10245352627322246, 0.8971816855998777, 0.00036478812689488436]
# 252 @JetBlue thanks!! Great service in #T5 already! #lovejetBlue
# probs=[0.02169693477901607, 0.0027631601700754634, 0.9755399050509109]
# 253 @usairways app is the worst one for airlines. Can't do anything once your original flight time has gone by. Useless.
# probs=[0.9999914151311643, 7.39906633039974e-06, 1.1858025047980913e-06]
# 254 @AmericanAir over the last year 50% of my flights have been delayed or Cancelled Flightled.  I'm done with you.
# probs=[0.9968334455930147, 0.0028694987906412945, 0.000297055616344177]
# 255 @USAirways - what is your policy regarding large-size passengers who cannot fit into a single coach class seat?
# probs=[0.9901228398635288, 0.009532195042840405, 0.00034496509363294]
# 256 @USAirways i worked with you and bought my own rental car when you failed to get me to the location i paid to get to and now....
# probs=[0.9904009960562419, 0.009596755339452277, 2.2486043042111826e-06]
# 257 @JetBlue is JFK still closed? Tryna get out of Ft Lauderdale on flight 502, just want to get home to nyc!
# probs=[0.7839518505709996, 0.21325527920698162, 0.0027928702220227832]
# 258 @USAirways How do I redeem my pass to the admirals club? I have 1 free visit with my barclay card membership. And can I bring a companion?
# probs=[0.0036240773311662805, 0.9853876712420133, 0.010988251426817237]
# 259 @AmericanAir Okay... If someone does it look for it now my fear is it will be lost forever. It's a very small item.
# probs=[0.9630058301732319, 0.009902838732216738, 0.027091331094555193]
# 260 @USAirways Decided to be a good sport and give you guys another shot. Flight delayed. Again.
# probs=[0.9487590118489672, 0.0023369065468262745, 0.048904081604208734]
# 261 @AmericanAir now the second flight I was put on was Cancelled Flightled with no explanation!! Missed my first meeting!!#outraged😡😡
# probs=[0.999778943197957, 0.000202567544888202, 1.848925715643451e-05]
# 262 @united hence why I've been asking for the customer service phone number so I can speak to a real person to get this sorted out
# probs=[0.9996281180365324, 0.00025398955550737034, 0.00011789240795885461]
# 263 @JetBlue I had 2 fight 2 get a credit for the value of my bag but I got it. #skytrax #jetblue #corpgreed #nevertakeno http://t.co/6MBVJFlpBM
# probs=[0.621238824472646, 0.3548621908851183, 0.023898984642236037]
# 264 @united Flight 211/ORD gate agent tried to prevent me from taking onboard a bag I've used for 15 years! Flight crew was more reasonable!
# probs=[0.9981202299726648, 6.692405450024327e-05, 0.0018128459728318598]
# ...
# probs=[0.9999522867513189, 3.663119287669492e-05, 1.1082055807986902e-05]
# 417 @united 4840 WTF! Why can't you update your times in a timely manner? You've known the fight was more delayed! Ur service is awful! @CNN
# probs=[0.9999902780668536, 8.37517181297583e-06, 1.3467613371106795e-06]
# 418 @AmericanAir @louprice13 @aacustomerservice. Apology not good enough. 4 planes with mechanical and 9 hours delayed unacceptable.
# probs=[0.9999970055558192, 5.498476995114104e-07, 2.4445964790117487e-06]
# 419 @AmericanAir here is the ticket they gave me after lying, raising their voice. With no explanation on what happened http://t.co/31cFHtK60r
# probs=[0.8808135577850236, 0.11443183142597081, 0.004754610788999837]
# 420 @SouthwestAir hi guys, do you have a general enquires email address please? Thanks David.
# probs=[0.0010770941661597201, 0.9975591438043999, 0.001363762029439875]
# 421 @USAirways flight was full.  1 open middle seat.  Did not want to sit there.  What is your policy?
# probs=[0.9664149550636265, 0.03358060172936753, 4.443207004598106e-06]
# 422 @USAirways would be less annoying if road conditions weren't getting worse with every min U keep passengers captive for no good reason.
# probs=[0.9999866417732822, 8.977163128668382e-06, 4.381063593495418e-06]
# 423 @USAirways 45 minutes on hold waiting to speak with an agent !! Come on #USAirways !!! Ridiculous #baggagelost #usairways
# probs=[0.9999985872443734, 7.947635543517625e-07, 6.179920692363137e-07]
# 424 @USAirways flights keep getting delayed and Cancelled Flighted with no information, worst customer service ever.
# probs=[0.9999996367773625, 1.6908246058497247e-08, 3.463143909226826e-07]
# 425 @SouthwestAir arrangements to reimburse me for the rental I had to get?
# probs=[0.7674695841886006, 0.22688643386153334, 0.005643981949863807]
# 426 @united I was well taken care of, thanks. I've already been sent a survey request & I'll share my positive experience (despite delay)
# probs=[0.8734635488143497, 0.0015405195768309007, 0.12499593160882365]
# 427 @JetBlue only w/ $70 upgrade. Unsure why she can't just switch someone around. I called 24 hrs in advance for this reason.
# probs=[0.997903897839065, 0.00198587208832387, 0.00011023007261308803]
# 428 @JetBlue 2 words: "staff training." What a joke-
# probs=[0.9907522695460543, 0.00311866187577203, 0.006129068578174439]
# 429 RT @JetBlue: Our fleet's on fleek. http://t.co/826Pkiq5HI
# probs=[8.812509708487761e-05, 0.9994439695961663, 0.0004679053067497948]
# 430 @VirginAmerica too bad you say it takes 10 to 14 days via YOUR confirmation email. When I inquired after 3 weeks you claim 6 to 8 weeks!
# probs=[0.9664765531864933, 0.03299775973611553, 0.0005256870773955811]
# 431 @united I received my luggage that also looked to be left in the snow when I arrived. I'm asking for all 50 people to be refunded.
# probs=[0.9941439370070546, 0.005352710870151301, 0.000503352122795432]
# 432 @AmericanAir there are no more flights via united when I arrive to DFW and my car is parked at IAH 😁
# probs=[0.8896967850061505, 0.10984720998614582, 0.0004560050077045732]
# 433 @united funny, both my flights yesterday were delayed because of mechanical issues. Rotten luck to get 2 planes in a row with "issues"...
# probs=[0.9998416948679967, 8.70177198295591e-05, 7.128741217376864e-05]
# 434 @SouthwestAir hey I'm flying from Tampa to Denver today and I want to know if there will be tv's in the seats like @JetBlue
# probs=[0.9612441404076972, 0.0316201341281664, 0.007135725464139732]
# 435 @united I didn't have time to take my wet clothes/suit back to the airport and wasn't going to pay for another cab to do so.
# probs=[0.9994170646632462, 0.0005821064141552936, 8.289225952774638e-07]
# 436 @USAirways who do I contact about my awful experience I had 2/15/15 with @USAirways Flight 713 BUF-CLT?
# probs=[0.9939133762702619, 0.003890979252223992, 0.002195644477514481]
# 437 @JetBlue got txt  40min after sched dpt, saying plane had just arrived @ JFK. Late Flightr txt w/ dpt gate change. Then 9:04 dpt for 7:40 flight.
# probs=[0.9999299322389622, 5.94748033225796e-05, 1.0592957712881152e-05]
# 438 @AmericanAir I've been calling your 1800 # all morning to change my name for an upcoming trip but am not able to get through. Please advise!
# probs=[0.4252456020833248, 0.5744594525915712, 0.00029494532510309913]
# 439 @jetblue the man with the smell left nd now there's this stupid girl asking me questions. can yall help.
# probs=[0.25582120984567847, 0.7401410027992357, 0.004037787355078987]
# 440 @AmericanAir about when can I see a new American Airlines credit card to replace my USAIRWAYS dividend MasterCard?
# probs=[0.21085573002364733, 0.7854075278522883, 0.0037367421240639396]
# 441 @VirginAmerica WTF is happening in PDX Late Flight March such that one way from SFO is ~$550?
# probs=[0.9283262552807059, 0.07101248079081222, 0.0006612639284822019]
# 442 @JetBlue sooo earlier i said i couldnt fly with you for my school trip but now i can! 😏
# probs=[0.7377919803960934, 0.24361025317263044, 0.018597766431279056]
# 443 @AmericanAir I had a 6am flight I can get no rest because I have to wait another 2 hours to receive an automated phone call. #neveragain
# probs=[0.9999989829589764, 9.666629272344116e-07, 5.0378089356642086e-08]
# 444 @AmericanAir wait times of 2 hours to talk with an exec plt agent, what is going on!!!
# probs=[0.999935239125081, 3.6014385752891386e-05, 2.8746489169058452e-05]
# 445 @USAirways i will be Cancelled Flighting my us airways credit card and choosing other airlines after my experience this week.
# probs=[0.9948498396347666, 0.004850817613839723, 0.0002993427513937838]
# 446 @united Delayed 7 hrs flight 5721 PIT/IAD, finally board the plane, sit half hour & crew is at their hrs limit & we deplane. Unacceptable.
# probs=[0.9999999381705768, 5.176656150267051e-08, 1.0062866864649794e-08]
# 447 @JetBlue Best airline name ever. Whenever I see it, I want to get on their plane to blue skies & sea. (And they DELIVER on that promise)
# probs=[0.7487995655353418, 0.03791925575581909, 0.21328117870884292]
# 448 “@united: @qlyss8 We don't want our customers to be frustrated. Thank you for your patience. ^JT” A lovely sentiment, but not a $180 one.
# probs=[0.38940140306974735, 0.0008441359089512796, 0.6097544610213067]
# 449 “@JetBlue: @sylvie75015 Good morning, Sylvie! Have a great flight! #yourock” > Thank you #JetBlue! @mxo42 @henrikwagner73 #JetBlueRocks
# probs=[0.0010953482082870657, 0.001869366927131463, 0.9970352848645809]
# 450 @united thanks for making sure they hear the message!
# probs=[0.6346856564758789, 0.04785090640740935, 0.317463437116715]
# 451 @VirginAmerica I’m looking forward to watching the Oscars on my flight home tomorrow. I might even get something bubbly to drink! ;)
# probs=[0.8018559088899646, 0.1407704618007405, 0.05737362930928987]
# 452 @united - well, now finally on board hopefully we take off this time and quickly. Well over an hour delay!!
# probs=[0.9862463530883737, 0.0010143419992412598, 0.012739304912381622]
# 453 @AmericanAir finally made it to chicago - 13 hours Late Flight.  Did get a $12 food voucher for my wait.about $1per/hr. Never again. Good bye.
# probs=[0.999994375004409, 7.576772954189044e-07, 4.867318291462098e-06]
# 454 @USAirways my vacation budget was blown bc of the lack of communication from USAirways. I will never use them again or refer anyone!
# probs=[0.9996471522509723, 6.518089787266406e-05, 0.0002876668511481621]
# 455 @AmericanAir I have a couple questions for you, if you’re available for PM?
# probs=[0.7552974822749513, 0.23834438782375153, 0.006358129901297551]
# 456 @united - we're sitting in UA1088 getting delayed because the operations can't find captain. #ridiculous #united
# probs=[0.9999687111281047, 2.239107623139427e-05, 8.897795666372115e-06]
# 457 @USAirways #695 might have been Cancelled Flighted? mechanical issue. 6 hours Late Flightr 100 people still waiting and Zero information. Please send help.
# probs=[0.9999999924389584, 7.5025302763271e-09, 5.850669401204537e-11]
# 458 @SouthwestAir DM Sent.
# probs=[0.33483039416756216, 0.567499849834663, 0.09766975599777532]
# 459 @JetBlue flight was Cancelled Flighted. Do I need to file a claim for the $50 credit I'm entitled to per yr bill of rights, or will it just be issued?
# probs=[0.990383861732212, 0.009609917531330643, 6.220736458037479e-06]
# 460 @AmericanAir although there was a 6 hour delay every single staff member from the ticket desk to the admirals club in was as sweet as pie
# probs=[0.9909860419480421, 5.445763479048052e-05, 0.008959500417168692]
# 461 Lol, k. “@JetBlue: Our fleet's on fleek. http://t.co/IUX94Rgc83”
# probs=[0.0012063880389147012, 0.9930793754731098, 0.00571423648797689]
# 462 @VirginAmerica I love the dancing little richard. cool beans.
# probs=[0.011253129221725526, 0.04527722036818008, 0.9434696504100938]
# 463 @united we needed them here asap. Will they make it on today's flight?
# probs=[0.8774930507579194, 0.10618624728957135, 0.01632070195250879]
# 464 @southwestair Hi, how do I add a flight to my account? Just created it
# probs=[0.2164261634624718, 0.7658737553888032, 0.017700081148722048]
# 465 @USAirways this is got to be the worst service I've ever seen with an airline. 3 Cancelled Flightled flights. Rude employees. Currently flight delayed
# probs=[0.999999969018774, 1.710948164873225e-08, 1.387175003649239e-08]
# 466 @SouthwestAir had to rebook through Atlanta & now drive to #Nashville. Had to pay ridiculous price difference. Bad weather good for business
# probs=[0.998086270831224, 0.00191038119506451, 3.347973712204749e-06]
# 467 @SouthwestAir trying to change my reservation, been on hold for 45 minutes, and can't do it online-was directed to call. Help?
# probs=[0.9998671649621459, 0.00013281462343140723, 2.0414419346311993e-08]
# 468 @SouthwestAir how does your pre boarding process work? Basically anyone who doesn't want to wait their turn can get a slip?
# probs=[0.997618748151666, 0.0023708439676348413, 1.0407880705841187e-05]
# 469 @united Usually an issue with Express our of SFO. Positive note: Mainline p.s. was enjoyable.
# probs=[0.6876745102563883, 0.022043791088798347, 0.29028169865481396]
# 470 @USAirways - been on hold with reservations for over 30 min already! #worstairline
# probs=[0.9978141860911791, 0.002090812298456229, 9.500161036249861e-05]
# 471 @USAirways disappointment? Making own arrangements for me & my sleeping toddler with zero assistance from USAir is maddening.
# probs=[0.9856470952689319, 0.003372914373307453, 0.01097999035775949]
# 472 @united Total BS.have 1st class seats for connecting flight. Your crew Late Flight. We miss connection. Had next plane. Yet u don't honor it??
# probs=[0.9999345325424738, 5.5770657120876596e-05, 9.696800403429502e-06]
# 473 @VirginAmerica Grouping Virgin in with the others now. BOS weather has exposed their actual Cus Serv model. Never Flight Booking Problems with Virgin again!
# probs=[0.7240776271653415, 0.26757954169002995, 0.00834283114463057]
# 474 @SouthwestAir please hire an efficiency consultant to manage your PHX baggage checkin. Way to many open kiosks with 100's of ppl waiting
# probs=[0.9998833219096135, 0.00010810706852572858, 8.571021859682556e-06]
# 475 @SouthwestAir Flight 4968 (N8325D) departs @MCO enroute to @NO_Airport http://t.co/fd4SnvKIeM
# probs=[0.006520349628637139, 0.986653662745521, 0.006825987625841586]
# 476 @united awesome new plane flight 1701
# probs=[0.1464867548044936, 0.07683568367401461, 0.7766775615214919]
# 477 @united that's what I thought! Thanks for the clarification!
# probs=[0.2561708915970379, 0.21607868126161106, 0.5277504271413513]
# 478 @united I'm not as sure as you are. http://t.co/HSMpbSF4UF
# probs=[0.21569858773259282, 0.6517277190712961, 0.13257369319610976]
# 479 @SouthwestAir seeing your workers time in and time out going above and beyond is why I love flying with you guys. Thank you!
# probs=[0.02836313582296853, 0.003656700019663101, 0.9679801641573662]
# 480 @JetBlue Thank you. Fingers crossed.
# probs=[0.019288556005121315, 0.07953221932638661, 0.9011792246684939]
# 481 @AmericanAir - Envoy Airlines is a disgrace to the AA family.  Nothing but delays and Cancelled Flightlations, week after week.
# probs=[0.9994149027630539, 0.0002942570558490785, 0.0002908401810917441]
# 482 @JetBlue I will. I love flying with you all. Great service.
# probs=[0.0795931092664488, 0.009288948322054257, 0.9111179424114964]
# 483 @USAirways i ve been told that you get a percentage on every plastic bottle that is sold around yout departure section...turn up the heat
# probs=[0.9958494100290765, 0.004084633817150394, 6.595615376713148e-05]
# 484 @united screwed over my professor. Maybe we should tell everyone about @Skiplagged ? #aviation #airport #airline #innovation #startups #tech
# probs=[0.860141015050334, 0.009327122082021116, 0.13053186286764162]
# 485 @USAirways @Beamske how about a real live person talk to the person whose luggage was lost for 4 days and vacation wrecked . @yorkshire2002
# probs=[0.9999837761223507, 3.3213139568352605e-06, 1.2902563697538496e-05]
# 486 @united On flight 1712 to Houston delayed duecto engine trouble. Willl you hold my connection to Argentina at Houston since I'm Late Flight now?
# probs=[0.9999586941922042, 4.045142182035421e-05, 8.54385975950827e-07]
# 487 @united is pri boarding for "Active Military" or only "In Uniform?" 90% can't travel in uniform for OPSEC reason, even on official travel
# probs=[0.5504105003491753, 0.41271803444177624, 0.03687146520905252]
# 488 @AmericanAir and how is this not a mechanical issue? All evidence points to the idea that it’s the ILS at CLL at fault, not the weather.
# probs=[0.9944766555385521, 0.004909861171812298, 0.0006134832896344587]
# 489 @AmericanAir machines are broken, lines are out the door for self service, cust. Support, and bag check in.
# probs=[0.9999633246758738, 3.095559810996787e-05, 5.719726009896726e-06]
# 490 @USAirways I was eventually given a flight to Memphis but only after I was taken off my original flight bc I was checked in as my father
# probs=[0.9927509480488104, 0.005872103840044633, 0.001376948111148739]
# 491 @SouthwestAir you only hear about the bad things. Flying the last to weekends, the flights and crews were awesome. Thank you. 👍👍
# probs=[0.018614155754173568, 0.0006332432801885328, 0.9807526009656372]
# 492 @JetBlue Awww thank you B6! Glad to hear it!  Made my day! & one last question do you have any idea what tail is operating flt 606 2maro? :)
# probs=[0.23901765188683294, 0.12856118746725273, 0.6324211606459177]
# 493 @AmericanAir you guys fail again.. all I need to do is use my voucher for a ticket but I can't do it online #yourphonesystemsucks
# probs=[0.993820274901411, 0.00616947827425496, 1.0246824335055208e-05]
# 494 @JetBlue can you tweet #closepwcs to get the word out?😢
# probs=[0.5155493521347116, 0.22419232995598656, 0.2602583179093034]
# 495 @SouthwestAir live in Atlanta but cant enroll in your Atlanta companion promotion. Error every time. Can you help? Also sent email. Thanks!
# probs=[0.23507655819078008, 0.7615492462141683, 0.0033741955950545295]
# 496 @united Hey, thanks again for helping me miss my buddies 30th bday, you guys are really a trashy company #shouldhaveflowndelta #unitedsucks
# probs=[0.5173797266867672, 0.004471675388189459, 0.4781485979250365]
# 497 @AmericanAir I was flying from Ft Lauderdale FL to Seattle WA on the 02/28/2015 until the 03/03/2015 and they don't want to honor my flight.
# probs=[0.056200226213637725, 0.9352753603462161, 0.008524413440145436]
# 498 @JetBlue 2 aisles of empty #evermoreroom seats and we can't move bc we didn't pay?! #nonsense #Waste #JetBlue #jetbluebos #cheap
# probs=[0.999051590359315, 0.000810303233711758, 0.0001381064069750681]
# 499 @AmericanAir should reconsider #usairways acquisition. Flight 1843 AA gold flyers insulted by attendant for hanging jacket!
# probs=[0.9687541607733937, 0.01672797547769589, 0.014517863748913363]
# Stream has ended, goodbye!
# Some statistics:
# penalty= 0.7023920897736583
# Your score is 100 / 100
# Connection closed
# You sent total of 500 signal(s) to server

# %% [markdown]
# Check the result

# %%
result
# Out:
# {'problems': [],
#  'n_signals': 500,
#  'penalty': 0.7023920897736583,
#  'missed_id': [],
#  'score': 100}

# %%
# remove empty values from buffers
tweets_df = tweets_df.head(tweet_counter)
tweets_df
# Out:
#                            time tweet_id
# 0    2023-10-14 18:31:04.474884        0  \
# 1    2023-10-14 18:31:05.711151        1
# 2    2023-10-14 18:31:07.691699        2
# 3    2023-10-14 18:31:08.631086        3
# 4    2023-10-14 18:31:10.763921        4
# ..                          ...      ...
# 495  2023-10-14 18:39:07.739907      495
# 496  2023-10-14 18:39:08.358925      496
# 497  2023-10-14 18:39:09.786725      497
# 498  2023-10-14 18:39:10.298451      498
# 499  2023-10-14 18:39:11.427413      499
#
#                                                   text  prob_neg prob_neutral
# 0                      @AmericanAir can I DM you info?  0.509991      0.43007  \
# 1    @united u Cancelled Flighted my flight from IA...  0.989542     0.010457
# 2    @united has once again earned a place as the w...   0.99802     0.001195
# 3                                      @jetblue thanks  0.325012     0.149823
# 4    @SouthwestAir: #VIPLiveintheVieyard - first ti...  0.998304     0.001661
# ..                                                 ...       ...          ...
# 495  @SouthwestAir live in Atlanta but cant enroll ...  0.235077     0.761549
# 496  @united Hey, thanks again for helping me miss ...   0.51738     0.004472
# 497  @AmericanAir I was flying from Ft Lauderdale F...    0.0562     0.935275
# 498  @JetBlue 2 aisles of empty #evermoreroom seats...  0.999052      0.00081
# 499  @AmericanAir should reconsider #usairways acqu...  0.968754     0.016728
#
#     prob_positive
# 0        0.059938
# 1        0.000001
# 2        0.000785
# 3        0.525164
# 4        0.000035
# ..            ...
# 495      0.003374
# 496      0.478149
# 497      0.008524
# 498      0.000138
# 499      0.014518
#
# [500 rows x 6 columns]

# %% [markdown]
# Save the log.

# %%
# after all you can dump your data/results and analyze it later
with open('results.pkl', 'wb') as output_f:
    pickle.dump([tweets_df, result], output_f)

# %% [markdown]
# ## Penalty Function
#
# The penalty for this project is the logloss measure of accuracy of sentiment classification
# $$LogLoss=-\frac{1}{N} \sum_{i=1}^N \left( y_{i,neg} \log(p_{i,neg}) + y_{i,neut} \log(p_{i,neut}) + y_{i,pos} \log(p_{i,pos}) \right),$$
# where $y_{i,c}=1$ when the tweet belongs to class $c$, and 0 otherwise; $p_{i,c}$ are predicted probabilities of classes.
